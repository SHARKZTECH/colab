# %% [markdown]
# <a href="https://colab.research.google.com/github/SHARKZTECH/colab/blob/main/stable_diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

if torch.cuda.is_available():
    print("CUDA is available on your system.")
    print("You have a CUDA-enabled GPU.")
else:
    print("CUDA is not available on your system.")
    print("You can only run computations on the CPU.")

# %%
from diffusers import StableDiffusionPipeline
import torch
from PIL import Image
from IPython.display import display

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float32)
pipe = pipe.to("cuda")

while True:
    # Get user input
    prompt = input("Enter a description (Type 'exit' to quit): ")

    if prompt.lower() in ["exit", "quit"]:
        print("Exiting the program.")
        break

    # Generate the image
    image = pipe(prompt).images[0]

    # Save the image locally
    # image_path = "astronaut_rides_horse.png"
    # image.save(image_path)

    # Display the image in the notebook
    display(image)

# Note: Commented out the image saving part to avoid cluttering the disk with images while testing in Colab.
# If you want to save images, you can uncomment the image saving code.
# Out:
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Enter a description (Type 'exit' to quit): astronut riding horse on mars
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7A770E367580>
